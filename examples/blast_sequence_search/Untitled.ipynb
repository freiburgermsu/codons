# %%
import re

sequence = r'C:\Users\Andrew Freiburger\Dropbox\My PC (DESKTOP-M302P50)\Documents\UVic Civil Engineering\Fundamental_model\codons\examples\translation-transcription\translation-41_proteins\protein_sequence.fasta'
with open(sequence) as input:
    lines = input.readlines()

for line in lines:
    if not re.search('>', line):
        print(line)
# Out:
# VHGWRKCL*
#
# ZBFBAHPTZZVEWRF*
#
# WGIIYS*
#
# GRYYVFCA*
#
# F*
#
# LLL*
#
# LZG*
#
# SCVFGFTHDTAVBBRSLSDCRWCKF*
#
# RFL*
#
# LFCTHGLERVVZCLWHKRCCSTRLKSLLLRGCABC*
#
# PVWW*
#
# GFK*
#
# HBYGIVVFCVSLVCLZSGLIK*
#
# LALL*
#
# CLLFSSLV*
#
# P*
#
# V*
#
# VS*
#
# PIDSCSBCWSCWCSHSRRTYYIGLGEZSDBFLCFSSLC*
#
# DDLRLYSCBVL*
#
# SSC*
#
# L*
#
# GSCZPIH*
#
# FRFHVYLLFWCLLSFEP*
#
# HICGSPLCAPTVTLRG*
#
# P*
#
# H*
#
# GAC*
#
# BLSTYSLFDLSKFZLKLKGTPVLZLKESZIBELVISLLSZGKLLIRDBDTLSVSTDVLVBTYRKLR*
#
# WHFT*
#
# FFTSSVWHTSSGL*
#
# FDFSDCSS*
#
# THFFYHVSILPFYAIBA*
#
# RLLHTVLHWLWHKLYGKT*
#
# LRACIKTAZADTAGLYTBFRIDVPSAESTGTZSVSVDRESTSTHDGPTEHVTSVBLFDVGYSVB*
#
# FVTPLAVDVVSIRSSBZGBKZIVHSYPILHHPGF*
#
# VPVIHTKPLFIRBFDZRCSCSRCFYLHSSTYIECTYISRFSKISLVSVTDFSLBGBVSTVFVPATRDSVPLHIIAPSSLIV*
#
# TGFBTLLVZPALYLYBTGRSVYVKFZDSKPPLPPDEWV*
#
# DTHPVV*
#
# SLKCLFYGSYGHLPWRYZYLAPFIZLI*
#
# C*

# %%
from Bio import Entrez

display(dir(Entrez))
# Out:
# ['HTTPError',
#  'URLError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_construct_cgi',
#  '_construct_params',
#  '_encode_options',
#  '_open',
#  '_update_ecitmatch_variables',
#  'api_key',
#  'ecitmatch',
#  'efetch',
#  'egquery',
#  'einfo',
#  'elink',
#  'email',
#  'epost',
#  'esearch',
#  'espell',
#  'esummary',
#  'io',
#  'max_tries',
#  'parse',
#  'read',
#  'sleep_between_tries',
#  'time',
#  'tool',
#  'urlencode',
#  'urlopen',
#  'warnings']
